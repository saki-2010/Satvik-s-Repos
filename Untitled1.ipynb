# %% [markdown]
# <a href="https://colab.research.google.com/github/saki-2010/Satvik-s-Repos/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#load in libraries
import cv2
from google.colab.patches import cv2_imshow
import time

# load in classifier
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
s = input("type the name of the image you want: ")
time.sleep(2.5)
print("the ai nigger automatic master bot is thinking")
time.sleep(2.5)
print("wait a sec brochacho")
time.sleep(2.5)
print("ok i got it")
time.sleep(2.5)
# load in image, and convert
img = cv2.imread(s)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

# draw bounding box around detected faces
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 10)

# display image
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1-807168755.py in <cell line: 0>()
#       6 # load in classifier
#       7 face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
# ----> 8 s = input("type the name of the image you want: ")
#       9 time.sleep(2.5)
#      10 print("the ai nigger automatic master bot is thinking")
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %%
#load in libraries
import cv2
from google.colab.patches import cv2_imshow
import time

# load in classifier
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
s = input("type the name of the image you want: ")

# load in image, and convert
img = cv2.imread(s)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

# draw bounding box around detected faces
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 10)

# display image
cv2_imshow(img)
# Out:
# type the name of the image you want: smyw.jpg
# what facial feature do you want to detect? (face, eyes, mouth, or nose)eyes
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipython-input-6-2865276807.py in <cell line: 0>()
#      14 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#      15 faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
# ---> 16 eyes = eyes_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
#      17
#      18 # draw bounding box around detected faces
#
# error: OpenCV(4.11.0) /io/opencv/modules/objdetect/src/cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'detectMultiScale'

# %%
# load in libraries
import cv2
from google.colab.patches import cv2_imshow

# load in classifier
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

# load in image, and convert
img = cv2.imread('smyw.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# detect eyes
eyes = eye_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

# draw bounding box around detected eyes
for (x, y, w, h) in eyes:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)

# display image
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
# load in our libraries
import face_recognition

#load in our images
known_image = face_recognition.load_image_file('syfm.jpg')
unknown_image = face_recognition.load_image_file('SYFM2.jpg')

# get face encodings for known faces
known_face_encoding = face_recognition.face_encodings(known_image)[0]
known_face_encodings = [known_face_encoding]

# detect faces in unknown images
face_locations = face_recognition.face_locations(unknown_image)
face_encodings = face_recognition.face_encodings(unknown_image, face_locations)

# compare faces, recognize faces
for fare_encoding in face_encodings:
  matches = face_recognition.compare_faces(known_face_encodings, face_encoding)
  name = "Unknown"

  face_distances = face_recognition.face_distance(known_face_encodings, face_encoding)
  best_match_index = np.argmin(face_distances)
  if True in matches:
    first_match_index = matches.index(True)
    name = known_face_names[first_match_index]

  print(f"Detected face: (name)")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-9-2404150558.py in <cell line: 0>()
#       1 # load in our libraries
# ----> 2 import face_recognition
#       3
#       4 #load in our images
#       5 known_image = face_recognition.load_image_file('syfm.jpg')
#
# /usr/local/lib/python3.11/dist-packages/face_recognition/__init__.py in <module>
#       5 __version__ = '1.2.3'
#       6
# ----> 7 from .api import load_image_file, face_locations, batch_face_locations, face_landmarks, face_encodings, compare_faces, face_distance
#
# /usr/local/lib/python3.11/dist-packages/face_recognition/api.py in <module>
#      24
#      25 cnn_face_detection_model = face_recognition_models.cnn_face_detector_model_location()
# ---> 26 cnn_face_detector = dlib.cnn_face_detection_model_v1(cnn_face_detection_model)
#      27
# ...
